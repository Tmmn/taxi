# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import numpy as np
import gzip
import shutil
import json
import os
import glob
import re

from ineqpy.inequality import atkinson, gini
from ineqpy.statistics import percentile

# %% [markdown]
# ## Reading different statistics from per taxi metrics

# %% [markdown]
# Adding `run_id` to the dictionary of results.

# %%
def add_run_id(fname, d, mode="per_taxi"):
    """
    Given the long filename from Spark, and a dict, this function
    cuts out the run_id from the filename, and adds it with a key
    `run_id` to the dictionary d.
    """
    if mode=="per_taxi":
        d["run_id"] = re.sub('^run_','',re.sub("_per_taxi_metrics.json.gz$",'',fname.split('/')[-1]))
    elif mode=="aggregates":
        d["run_id"] = re.sub('^run_','',re.sub("_aggregates.csv.gz$",'',fname.split('/')[-1]))
    return d

# %% [markdown]
# Here, we could calculate everything we need from the incomes, online ratios etc. at once.

# %%
def calculate_ratio(data,thres=20):
    upper_thres = np.percentile(data,100-thres)
    lower_thres = np.percentile(data,thres)
    
    upper_mean = np.mean(data[np.where(data>upper_thres)])
    lower_mean = np.mean(data[np.where(data>lower_thres)])
    
    return upper_mean/lower_mean

# %%
def calc_inequality_indices(t):
    """
    Given a dictionary with the results, it calculates the different inequality indices
    of the incomes.
    """
    if "trip_avg_price" in t:
        p = np.array(list(map(float,t["trip_avg_price"])))
    elif "trip_income" in t:
        p=np.array(list(map(float,t["trip_income"])))
    else:
        return {
            "run_id" : t["run_id"],
            "atkinson" : None,
            "gini" : None,
            "20/20_ratio" : None
        
        }
    
    return {
        "run_id" : t["run_id"],
        "atkinson" : atkinson(p),
        "gini" : gini(p),
        "20/20_ratio" : calculate_ratio(p)
    }

# %%
# Processing per_taxi_metrics files
files = glob.glob('../results/run_simple*_per_taxi_metrics.json.gz')
data_ineq = []

for filename in files:
    try:
        with gzip.open(filename, 'rt') as f:
            content = f.read()
            lines = content.split('\n')
            if len(lines) >= 2:
                raw_json = lines[-2]
                # Parse JSON and apply transformations
                d = json.loads(raw_json)
                d = add_run_id(filename, d)
                result = calc_inequality_indices(d)
                data_ineq.append(result)
    except Exception as e:
        print(f"Error processing {filename}: {e}")

ineq_df = pd.DataFrame(data_ineq)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(ineq_df['atkinson'],ineq_df['gini'],'bo',alpha=1)
plt.xlabel('atkinson')
plt.ylabel('gini')
# Out:
# Text(0, 0.5, 'gini')

# %%
plt.plot(ineq_df['atkinson'],ineq_df['20/20_ratio'],'bo',alpha=0.1)
plt.xlabel('atkinson')
plt.ylabel('20/20 ratio')

# %% [markdown]
# ## Reading the configuration data

# %%
configs = []
with gzip.open('../configs/2019_all.conf.gz') as f:
    for line in f.readlines():
        configs.append(json.loads(line))

configs_df = pd.DataFrame.from_dict(configs)

# %% [markdown]
# ## Reading the aggregate csv files

# %%
# Processing aggregate CSV files
files_agg = glob.glob('../results/run_2019*_aggregates.csv.gz')
data_agg = []

for filename in files_agg:
    try:
        # Assuming index_col=0
        df_temp = pd.read_csv(filename, index_col=0)

        if not df_temp.empty:
            # Get the last row
            last_row = df_temp.iloc[-1].to_dict()
            # Add run_id
            last_row = add_run_id(filename, last_row, mode="aggregates")
            data_agg.append(last_row)
    except Exception as e:
        print(f"Error processing {filename}: {e}")

aggregates_df = pd.DataFrame(data_agg)

# %% [markdown]
# ## Merging and cleaning the joined results

# %%
# setting run_ids as index for all three dataframes
configs_df['run_id'] = configs_df['run_id'].map(lambda s: re.sub('\.conf','',s))
configs_df.set_index('run_id',inplace=True)

# %%
ineq_df.set_index('run_id',inplace=True)
aggregates_df.set_index('run_id',inplace=True)

# %%
# joining the different results
merged = configs_df.join(ineq_df).join(aggregates_df,rsuffix="_2")

# dropping one row that belongs to the base config
merged.drop('2019_02_14_base',inplace=True)
# adding a geom column from the run_ids
merged["geom"]=merged.index.map(lambda s: re.sub(r'^.+geom_([0-9]).+$',r'\1',s))

def select_not_nan(x,y):
    """
    Out of two elements, returns the one that is not a pandas NaN.
    If both are NaNs, returns a NaN.
    """
    if pd.isnull(x):
        return y
    else:
        return x

# merging names from old and new code to one single column
for prefix in ['avg', 'std']:
    merged[prefix+'_trip_avg_price'] = merged[prefix+'_trip_avg_price'].combine(merged[prefix+'_trip_income'],select_not_nan)
    merged.drop(prefix+'_trip_income',axis=1,inplace=True)

# %%
# deleting unnecessary columns
merged.drop([
    "show_plot", 
    "show_map_labels", 
    "show_pending", 
    "avg_timestamp", 
    "std_timestamp",
    "0",
    "avg_request_lengths_2"
],axis=1,inplace=True)

# %%
# saving results
merged.to_csv('results.csv.gz',compression='gzip')

# %%
merged.head().T
# Out:
# run_id                            2019_02_14_base_d_120_R_0_05_alg_nearest_geom_0_behav_go_back_ic_base_reset_false  \
# R                                                                               0.05
# avg_request_lengths                                                             20.1
# base_coords                                                                 [20, 20]
# batch_size                                                                       180
# behaviour                                                                    go_back
# cost_per_unit                                                                     13
# d                                                                                120
# hard_limit                                                                        10
# initial_conditions                                                              base
# log                                                                            False
# m                                                                                 40
# matching                                                                     nearest
# max_request_waiting_time                                                          30
# max_time                                                                       14400
# n                                                                                 40
# num_taxis                                                                       1111
# price_fixed                                                                      450
# price_per_dist                                                                   140
# request_destination_distributions                                                NaN
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# request_rate                                                                       3
# reset_time                                                                       NaN
# 20/20_ratio                                                                    1.693
# atkinson                                                                    0.114132
# gini                                                                        0.357599
# avg_ratio_cruising                                                             0.008
# avg_ratio_online                                                              0.0709
# avg_ratio_serving                                                             0.0537
# avg_ratio_to_request                                                          0.0172
# avg_ratio_waiting                                                              0.921
# avg_request_completed                                                         0.9904
# avg_request_last_waiting_times                                                   5.8
# avg_time_cruising                                                                NaN
# avg_time_serving                                                                 NaN
# avg_time_to_request                                                              NaN
# avg_time_waiting                                                                 NaN
# avg_trip_avg_length                                                          19.4423
# avg_trip_avg_price                                                           93935.9
# std_ratio_cruising                                                            0.0048
# std_ratio_online                                                              0.0456
# std_ratio_serving                                                             0.0349
# std_ratio_to_request                                                          0.0108
# std_ratio_waiting                                                               0.05
# std_request_completed                                                              0
# std_request_last_waiting_times                                                     0
# std_request_lengths                                                                0
# std_time_cruising                                                                NaN
# std_time_serving                                                                 NaN
# std_time_to_request                                                              NaN
# std_time_waiting                                                                 NaN
# std_trip_avg_length                                                           3.3033
# std_trip_avg_price                                                           60962.1
# timestamp                                                                      14400
# geom                                                                               0
#
# run_id                            2019_02_14_base_d_120_R_0_05_alg_nearest_geom_0_behav_stay_ic_base_reset_false  \
# R                                                                               0.05
# avg_request_lengths                                                             20.1
# base_coords                                                                 [20, 20]
# batch_size                                                                       180
# behaviour                                                                       stay
# cost_per_unit                                                                     13
# d                                                                                120
# hard_limit                                                                        10
# initial_conditions                                                              base
# log                                                                            False
# m                                                                                 40
# matching                                                                     nearest
# max_request_waiting_time                                                          30
# max_time                                                                       14400
# n                                                                                 40
# num_taxis                                                                       1111
# price_fixed                                                                      450
# price_per_dist                                                                   140
# request_destination_distributions                                                NaN
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# request_rate                                                                       3
# reset_time                                                                       NaN
# 20/20_ratio                                                                  1.61864
# atkinson                                                                    0.500546
# gini                                                                        0.658725
# avg_ratio_cruising                                                                 0
# avg_ratio_online                                                              0.0619
# avg_ratio_serving                                                             0.0542
# avg_ratio_to_request                                                          0.0077
# avg_ratio_waiting                                                             0.9381
# avg_request_completed                                                         0.9983
# avg_request_last_waiting_times                                                     1
# avg_time_cruising                                                                NaN
# avg_time_serving                                                                 NaN
# avg_time_to_request                                                              NaN
# avg_time_waiting                                                                 NaN
# avg_trip_avg_length                                                          10.1348
# avg_trip_avg_price                                                           98131.6
# std_ratio_cruising                                                                 0
# std_ratio_online                                                              0.0793
# std_ratio_serving                                                             0.0691
# std_ratio_to_request                                                          0.0102
# std_ratio_waiting                                                             0.0793
# std_request_completed                                                              0
# std_request_last_waiting_times                                                     0
# std_request_lengths                                                                0
# std_time_cruising                                                                NaN
# std_time_serving                                                                 NaN
# std_time_to_request                                                              NaN
# std_time_waiting                                                                 NaN
# std_trip_avg_length                                                            10.03
# std_trip_avg_price                                                            124557
# timestamp                                                                      14400
# geom                                                                               0
#
# run_id                            2019_02_14_base_d_120_R_0_05_alg_nearest_geom_0_behav_stay_ic_home_reset_false  \
# R                                                                               0.05
# avg_request_lengths                                                             20.1
# base_coords                                                                 [20, 20]
# batch_size                                                                       180
# behaviour                                                                       stay
# cost_per_unit                                                                     13
# d                                                                                120
# hard_limit                                                                        10
# initial_conditions                                                              home
# log                                                                            False
# m                                                                                 40
# matching                                                                     nearest
# max_request_waiting_time                                                          30
# max_time                                                                       14400
# n                                                                                 40
# num_taxis                                                                       1111
# price_fixed                                                                      450
# price_per_dist                                                                   140
# request_destination_distributions                                                NaN
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# request_rate                                                                       3
# reset_time                                                                       NaN
# 20/20_ratio                                                                  1.27269
# atkinson                                                                   0.0264818
# gini                                                                        0.169026
# avg_ratio_cruising                                                                 0
# avg_ratio_online                                                              0.0593
# avg_ratio_serving                                                             0.0542
# avg_ratio_to_request                                                          0.0051
# avg_ratio_waiting                                                             0.9407
# avg_request_completed                                                         0.9982
# avg_request_last_waiting_times                                                     1
# avg_time_cruising                                                                NaN
# avg_time_serving                                                                 NaN
# avg_time_to_request                                                              NaN
# avg_time_waiting                                                                 NaN
# avg_trip_avg_length                                                          20.2604
# avg_trip_avg_price                                                           98594.2
# std_ratio_cruising                                                                 0
# std_ratio_online                                                              0.0179
# std_ratio_serving                                                             0.0163
# std_ratio_to_request                                                          0.0017
# std_ratio_waiting                                                             0.0179
# std_request_completed                                                              0
# std_request_last_waiting_times                                                     0
# std_request_lengths                                                                0
# std_time_cruising                                                                NaN
# std_time_serving                                                                 NaN
# std_time_to_request                                                              NaN
# std_time_waiting                                                                 NaN
# std_trip_avg_length                                                           2.3855
# std_trip_avg_price                                                           29552.2
# timestamp                                                                      14400
# geom                                                                               0
#
# run_id                            2019_02_14_base_d_120_R_0_05_alg_nearest_geom_0_behav_stay_ic_home_reset_true  \
# R                                                                               0.05
# avg_request_lengths                                                             20.1
# base_coords                                                                 [20, 20]
# batch_size                                                                       180
# behaviour                                                                       stay
# cost_per_unit                                                                     13
# d                                                                                120
# hard_limit                                                                        10
# initial_conditions                                                              home
# log                                                                            False
# m                                                                                 40
# matching                                                                     nearest
# max_request_waiting_time                                                          30
# max_time                                                                       14400
# n                                                                                 40
# num_taxis                                                                       1111
# price_fixed                                                                      450
# price_per_dist                                                                   140
# request_destination_distributions                                                NaN
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# request_rate                                                                       3
# reset_time                                                                      2900
# 20/20_ratio                                                                  1.23929
# atkinson                                                                   0.0216887
# gini                                                                        0.153985
# avg_ratio_cruising                                                            0.0002
# avg_ratio_online                                                              0.0587
# avg_ratio_serving                                                             0.0539
# avg_ratio_to_request                                                          0.0048
# avg_ratio_waiting                                                             0.9411
# avg_request_completed                                                          0.998
# avg_request_last_waiting_times                                                     1
# avg_time_cruising                                                                NaN
# avg_time_serving                                                                 NaN
# avg_time_to_request                                                              NaN
# avg_time_waiting                                                                 NaN
# avg_trip_avg_length                                                          20.3229
# avg_trip_avg_price                                                           97965.2
# std_ratio_cruising                                                            0.0005
# std_ratio_online                                                              0.0162
# std_ratio_serving                                                             0.0148
# std_ratio_to_request                                                          0.0015
# std_ratio_waiting                                                             0.0162
# std_request_completed                                                              0
# std_request_last_waiting_times                                                     0
# std_request_lengths                                                                0
# std_time_cruising                                                                NaN
# std_time_serving                                                                 NaN
# std_time_to_request                                                              NaN
# std_time_waiting                                                                 NaN
# std_trip_avg_length                                                           2.3289
# std_trip_avg_price                                                           26770.5
# timestamp                                                                      14400
# geom                                                                               0
#
# run_id                            2019_02_14_base_d_120_R_0_05_alg_nearest_geom_1_behav_go_back_ic_base_reset_false
# R                                                                               0.05
# avg_request_lengths                                                             24.9
# base_coords                                                                 [20, 20]
# batch_size                                                                       180
# behaviour                                                                    go_back
# cost_per_unit                                                                     13
# d                                                                                120
# hard_limit                                                                        10
# initial_conditions                                                              base
# log                                                                            False
# m                                                                                 40
# matching                                                                     nearest
# max_request_waiting_time                                                          30
# max_time                                                                       14400
# n                                                                                 40
# num_taxis                                                                       1111
# price_fixed                                                                      450
# price_per_dist                                                                   140
# request_destination_distributions                                                NaN
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# request_rate                                                                       2
# reset_time                                                                       NaN
# 20/20_ratio                                                                  1.95499
# atkinson                                                                     0.22541
# gini                                                                        0.477601
# avg_ratio_cruising                                                            0.0045
# avg_ratio_online                                                              0.0551
# avg_ratio_serving                                                             0.0429
# avg_ratio_to_request                                                          0.0123
# avg_ratio_waiting                                                             0.9404
# avg_request_completed                                                         0.9641
# avg_request_last_waiting_times                                                   4.7
# avg_time_cruising                                                                NaN
# avg_time_serving                                                                 NaN
# avg_time_to_request                                                              NaN
# avg_time_waiting                                                                 NaN
# avg_trip_avg_length                                                          21.6028
# avg_trip_avg_price                                                           75741.3
# std_ratio_cruising                                                            0.0035
# std_ratio_online                                                              0.0491
# std_ratio_serving                                                             0.0384
# std_ratio_to_request                                                          0.0108
# std_ratio_waiting                                                             0.0523
# std_request_completed                                                              0
# std_request_last_waiting_times                                                     0
# std_request_lengths                                                                0
# std_time_cruising                                                                NaN
# std_time_serving                                                                 NaN
# std_time_to_request                                                              NaN
# std_time_waiting                                                                 NaN
# std_trip_avg_length                                                            7.977
# std_trip_avg_price                                                           67615.8
# timestamp                                                                      14400
# geom                                                                               1
