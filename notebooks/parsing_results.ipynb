# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import numpy as np
import gzip
import shutil
import json
import os
import glob
import re

from ineqpy.inequality import atkinson, gini
from ineqpy.statistics import percentile

# %% [markdown]
# ## Reading different statistics from per taxi metrics

# %% [markdown]
# Adding `run_id` to the dictionary of results.

# %%
def add_run_id(fname, d, mode="per_taxi"):
    """
    Given the long filename from Spark, and a dict, this function
    cuts out the run_id from the filename, and adds it with a key
    `run_id` to the dictionary d.
    """
    base_name = os.path.basename(fname)
    if mode=="per_taxi":
        d["run_id"] = re.sub(r'^run_','',re.sub(r"_per_taxi_metrics.json.gz$",'',base_name))
    elif mode=="aggregates":
        d["run_id"] = re.sub(r'^run_','',re.sub(r"_aggregates.csv.gz$",'',base_name))
    elif mode=="config":
        d["run_id"] = re.sub(r'\.conf$', '', base_name)
    return d

# %% [markdown]
# Here, we could calculate everything we need from the incomes, online ratios etc. at once.

# %%
def calculate_ratio(data,thres=20):
    upper_thres = np.percentile(data,100-thres)
    lower_thres = np.percentile(data,thres)
    
    upper_mean = np.mean(data[np.where(data>upper_thres)])
    lower_mean = np.mean(data[np.where(data>lower_thres)])
    
    return upper_mean/lower_mean

# %%
def calc_inequality_indices(t):
    """
    Given a dictionary with the results, it calculates the different inequality indices
    of the incomes.
    """
    if "trip_avg_price" in t:
        p = np.array(list(map(float,t["trip_avg_price"])))
    elif "trip_income" in t:
        p=np.array(list(map(float,t["trip_income"])))
    else:
        return {
            "run_id" : t["run_id"],
            "atkinson" : None,
            "gini" : None,
            "20/20_ratio" : None
        
        }
    
    return {
        "run_id" : t["run_id"],
        "atkinson" : atkinson(p),
        "gini" : gini(p),
        "20/20_ratio" : calculate_ratio(p)
    }

# %%
# Processing per_taxi_metrics files
files = glob.glob('../results/passenger_fairness/run_test*_per_taxi_metrics.json.gz')
data_ineq = []

for filename in files:
    try:
        with gzip.open(filename, 'rt') as f:
            content = f.read()
            lines = content.split('\n')
            if len(lines) >= 2:
                raw_json = lines[-2]
                # Parse JSON and apply transformations
                d = json.loads(raw_json)
                d = add_run_id(filename, d)
                result = calc_inequality_indices(d)
                data_ineq.append(result)
    except Exception as e:
        print(f"Error processing {filename}: {e}")

ineq_df = pd.DataFrame(data_ineq)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(ineq_df['atkinson'],ineq_df['gini'],'bo',alpha=0.3)
plt.xlabel('atkinson')
plt.ylabel('gini')
# Out:
# Text(0, 0.5, 'gini')

# %%
plt.plot(ineq_df['atkinson'],ineq_df['20/20_ratio'],'bo',alpha=0.1)
plt.xlabel('atkinson')
plt.ylabel('20/20 ratio')
# Out:
# Text(0, 0.5, '20/20 ratio')

# %% [markdown]
# ## Reading the configuration data

# %%
configs = []
config_files = glob.glob('../configs/passenger_fairness/*.conf')

for filename in config_files:
    with open(filename, 'r') as f:
        try:
            d = json.load(f)
            d = add_run_id(filename, d, mode="config")
            configs.append(d)
        except Exception as e:
            print(f"Error reading {filename}: {e}")

configs_df = pd.DataFrame.from_records(configs)

# %% [markdown]
# ## Reading the aggregate csv files

# %%
# Processing aggregate CSV files
files_agg = glob.glob('../results/passenger_fairness/run_test*_aggregates.csv.gz')
data_agg = []

for filename in files_agg:
    try:
        # Assuming index_col=0
        df_temp = pd.read_csv(filename, index_col=0)

        if not df_temp.empty:
            # Get the last row
            last_row = df_temp.iloc[-1].to_dict()
            # Add run_id
            last_row = add_run_id(filename, last_row, mode="aggregates")
            data_agg.append(last_row)
    except Exception as e:
        print(f"Error processing {filename}: {e}")

aggregates_df = pd.DataFrame(data_agg)

# %% [markdown]
# ## Merging and cleaning the joined results

# %%
# setting run_ids as index for all three dataframes
configs_df['run_id'] = configs_df['run_id'].map(lambda s: re.sub(r'\.conf','',s))
configs_df.set_index('run_id',inplace=True)

# %%
ineq_df.set_index('run_id',inplace=True)
aggregates_df.set_index('run_id',inplace=True)

# %%
# joining the different results
merged = configs_df.join(ineq_df).join(aggregates_df,rsuffix="_2")

# dropping one row that belongs to the base config
merged.drop('test',inplace=True)
# adding a geom column from the run_ids
merged["geom"]=merged.index.map(lambda s: re.sub(r'^.+geom_([0-9]).+$',r'\1',s))

def select_not_nan(x,y):
    """
    Out of two elements, returns the one that is not a pandas NaN.
    If both are NaNs, returns a NaN.
    """
    if pd.isnull(x):
        return y
    else:
        return x

# merging names from old and new code to one single column
# for prefix in ['avg', 'std']:
#     merged[prefix+'_trip_avg_price'] = merged[prefix+'_trip_avg_price'].combine(merged[prefix+'_trip_income'],select_not_nan)
#     merged.drop(prefix+'_trip_income',axis=1,inplace=True)

# %%
# deleting unnecessary columns
merged.drop([
    "show_plot", 
    "show_map_labels", 
    "show_pending", 
    "avg_timestamp", 
    "std_timestamp"
],axis=1,inplace=True)

# %%
# saving results
merged.to_csv('results.csv.gz',compression='gzip')

# %%
merged.head().T
# Out:
# run_id                            test_d_258_R_0_20_alg_nearest_geom_0_behav_stay_ic_base_reset_false  \
# n                                                                                 40
# m                                                                                 40
# price_fixed                                                                        2
# base_coords                                                                 [20, 20]
# price_per_dist                                                                     1
# hard_limit                                                                        10
# cost_per_unit                                                                  0.008
# log                                                                            False
# max_request_waiting_time                                                         720
# max_time                                                                      2900.0
# batch_size                                                                       181
# d                                                                              258.0
# num_taxis                                                                        240
# avg_request_lengths                                                             20.2
# request_rate                                                                2.376238
# matching                                                                     nearest
# behaviour                                                                       stay
# initial_conditions                                                              base
# reset                                                                          false
# geom                                                                               0
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# R                                                                                0.2
# request_destination_distributions                                                NaN
# atkinson                                                                    0.071915
# gini                                                                        0.261867
# 20/20_ratio                                                                 1.335415
# timestamp                                                                     3077.0
# avg_trip_income                                                             664.3438
# std_trip_income                                                             304.7087
# avg_time_serving                                                            608.8833
# std_time_serving                                                               280.4
# avg_time_cruising                                                             2.5292
# std_time_cruising                                                             6.2148
# avg_time_waiting                                                           2350.2208
# std_time_waiting                                                            336.4119
# avg_time_to_request                                                         114.3667
# std_time_to_request                                                          57.6675
#
# run_id                            test_d_258_R_0_20_alg_nearest_geom_1_behav_stay_ic_base_reset_false  \
# n                                                                                 40
# m                                                                                 40
# price_fixed                                                                        2
# base_coords                                                                 [20, 20]
# price_per_dist                                                                     1
# hard_limit                                                                        10
# cost_per_unit                                                                  0.008
# log                                                                            False
# max_request_waiting_time                                                         720
# max_time                                                                      2900.0
# batch_size                                                                       181
# d                                                                              258.0
# num_taxis                                                                        240
# avg_request_lengths                                                             25.0
# request_rate                                                                    1.92
# matching                                                                     nearest
# behaviour                                                                       stay
# initial_conditions                                                              base
# reset                                                                          false
# geom                                                                               1
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# R                                                                                0.2
# request_destination_distributions                                                NaN
# atkinson                                                                     0.12657
# gini                                                                        0.361596
# 20/20_ratio                                                                 1.449631
# timestamp                                                                     3077.0
# avg_trip_income                                                             653.2503
# std_trip_income                                                             411.1875
# avg_time_serving                                                             609.675
# std_time_serving                                                            384.9921
# avg_time_cruising                                                             2.1958
# std_time_cruising                                                             5.5241
# avg_time_waiting                                                              2355.2
# std_time_waiting                                                             458.016
# avg_time_to_request                                                         108.9292
# std_time_to_request                                                          74.6944
#
# run_id                            test_d_258_R_0_20_alg_nearest_geom_2_behav_stay_ic_base_reset_false  \
# n                                                                                 40
# m                                                                                 40
# price_fixed                                                                        2
# base_coords                                                                 [20, 20]
# price_per_dist                                                                     1
# hard_limit                                                                        10
# cost_per_unit                                                                  0.008
# log                                                                            False
# max_request_waiting_time                                                         720
# max_time                                                                      2900.0
# batch_size                                                                       181
# d                                                                              258.0
# num_taxis                                                                        240
# avg_request_lengths                                                             13.5
# request_rate                                                                3.555556
# matching                                                                     nearest
# behaviour                                                                       stay
# initial_conditions                                                              base
# reset                                                                          false
# geom                                                                               2
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# R                                                                                0.2
# request_destination_distributions  [{'location': [20, 20], 'strength': 1, 'sigma'...
# atkinson                                                                    0.098188
# gini                                                                        0.348082
# 20/20_ratio                                                                 1.677938
# timestamp                                                                     3077.0
# avg_trip_income                                                              746.068
# std_trip_income                                                             462.4382
# avg_time_serving                                                            678.7542
# std_time_serving                                                            420.1991
# avg_time_cruising                                                             0.0208
# std_time_cruising                                                             0.1428
# avg_time_waiting                                                           2098.5583
# std_time_waiting                                                            615.8544
# avg_time_to_request                                                         298.6667
# std_time_to_request                                                         197.2195
#
# run_id                            test_d_258_R_0_20_alg_nearest_geom_3_behav_stay_ic_base_reset_false  \
# n                                                                                 40
# m                                                                                 40
# price_fixed                                                                        2
# base_coords                                                                 [20, 20]
# price_per_dist                                                                     1
# hard_limit                                                                        10
# cost_per_unit                                                                  0.008
# log                                                                            False
# max_request_waiting_time                                                         720
# max_time                                                                      2900.0
# batch_size                                                                       181
# d                                                                              258.0
# num_taxis                                                                        240
# avg_request_lengths                                                             21.9
# request_rate                                                                2.191781
# matching                                                                     nearest
# behaviour                                                                       stay
# initial_conditions                                                              base
# reset                                                                          false
# geom                                                                               3
# request_origin_distributions       [{'location': [20, 20], 'strength': 1, 'sigma'...
# R                                                                                0.2
# request_destination_distributions  [{'location': [20, 20], 'strength': 1, 'sigma'...
# atkinson                                                                    0.354437
# gini                                                                         0.60589
# 20/20_ratio                                                                 2.309131
# timestamp                                                                     3077.0
# avg_trip_income                                                             537.1384
# std_trip_income                                                             614.7443
# avg_time_serving                                                            488.0833
# std_time_serving                                                            558.6692
# avg_time_cruising                                                             0.2708
# std_time_cruising                                                             1.6065
# avg_time_waiting                                                           2391.2125
# std_time_waiting                                                            791.1686
# avg_time_to_request                                                         196.4333
# std_time_to_request                                                         232.7778
#
# run_id                            test_d_258_R_0_20_alg_nearest_geom_6_behav_stay_ic_base_reset_false
# n                                                                                 40
# m                                                                                 40
# price_fixed                                                                        2
# base_coords                                                                 [20, 20]
# price_per_dist                                                                     1
# hard_limit                                                                        10
# cost_per_unit                                                                  0.008
# log                                                                            False
# max_request_waiting_time                                                         720
# max_time                                                                      2900.0
# batch_size                                                                       181
# d                                                                              258.0
# num_taxis                                                                        240
# avg_request_lengths                                                             22.7
# request_rate                                                                2.114537
# matching                                                                     nearest
# behaviour                                                                       stay
# initial_conditions                                                              base
# reset                                                                          false
# geom                                                                               6
# request_origin_distributions       [{'location': [12, 12], 'strength': 5, 'sigma'...
# R                                                                                0.2
# request_destination_distributions                                                NaN
# atkinson                                                                    0.142039
# gini                                                                        0.385918
# 20/20_ratio                                                                 1.513379
# timestamp                                                                     3077.0
# avg_trip_income                                                             657.6037
# std_trip_income                                                             442.1824
# avg_time_serving                                                            609.1792
# std_time_serving                                                            410.6485
# avg_time_cruising                                                             2.6875
# std_time_cruising                                                             6.4218
# avg_time_waiting                                                           2351.9875
# std_time_waiting                                                            490.1963
# avg_time_to_request                                                         112.1458
# std_time_to_request                                                          80.0117
